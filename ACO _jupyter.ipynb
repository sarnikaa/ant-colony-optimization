# %% [markdown]
# # Ant Colony Optimization (ACO)

# %% [markdown]
# importing inbuilt libraries

# %%
import tkinter as tk
import matplotlib.pyplot as plt
from tkinter import Label, Entry, Button, Text
import networkx as nx
import random
import math
from PIL import Image, ImageTk

# %% [markdown]
# constants used

# %%
# Constants
NUM_ANTS = 100
NUM_CITIES = 100
ALPHA = 1.0
BETA = 2.0
EVAPORATION_RATE = 0.5
Q = 100
INITIAL_PHEROMONE = 1.0
MAX_DISTANCE = 1000

# %% [markdown]
# initializing arrays

# %%
# City locations (randomly generated)
locations = [(random.uniform(0, MAX_DISTANCE), random.uniform(0, MAX_DISTANCE)) for _ in range(NUM_CITIES)]
# Initialize pheromone levels
pheromones = [[INITIAL_PHEROMONE] * NUM_CITIES for _ in range(NUM_CITIES)]
# Initializing distances between cities
distances = [[0] * NUM_CITIES for _ in range(NUM_CITIES)]

# %% [markdown]
# calculating distance between cities

# %%
for i in range(NUM_CITIES):
    for j in range(i + 1, NUM_CITIES):
        dx = locations[i][0] - locations[j][0]
        dy = locations[i][1] - locations[j][1]
        distances[i][j] = distances[j][i] = math.sqrt(dx**2 + dy**2)

# %% [markdown]
# Ant class

# %%
class Ant:
    probabilities = [] 
    def __init__(self):
        self.visited = [False] * NUM_CITIES
        self.tour = []
 

    def select_next_city(self, current_city):
        print("Current city:", current_city)
        # Calculate the probability to move to each unvisited city
        probabilities = [0.0] * NUM_CITIES
        total = 0.0
        for city in range(NUM_CITIES):
            if not self.visited[city]:
                print("Calculating probability for city:", city)
                pheromone = pheromones[current_city][city]
                print("Pheromone level for edge (", current_city, ",", city, "):", pheromone)
                distance = distances[current_city][city]
                probabilities[city] = (pheromone ** ALPHA) * ((1 / distance) ** BETA)
                
                total += probabilities[city]
        print("Normalized probabilities:", probabilities)
        # Choose the next city based on probabilities
        if total > 0:
            print("Total probability:", total)
            r = random.uniform(0, total)
            for city in range(NUM_CITIES):
                if not self.visited[city]:
                    r -= probabilities[city]
                    
                    if r <= 0:
                        print("Next city selected:", city)
                        return city

        # If all cities have been visited, return to the starting city
        print("All cities visited. Returning to the starting city.")
      
        return self.tour[0]


    def find_tour(self):
        current_city = random.randint(0, NUM_CITIES - 1)
        self.tour = [current_city]
        self.visited[current_city] = True
        while len(self.tour) < NUM_CITIES:
            next_city = self.select_next_city(current_city)
            self.tour.append(next_city)
            self.visited[next_city] = True
            current_city = next_city

    def tour_length(self):
        total_length = 0
        for i in range(NUM_CITIES):
            total_length += distances[self.tour[i - 1]][self.tour[i]]
        return total_length

# %% [markdown]
# ACO functions

# %%
def update_pheromones(ants):
    for i in range(NUM_CITIES):
        for j in range(i + 1, NUM_CITIES):
            evaporation = (1 - EVAPORATION_RATE) * pheromones[i][j]
            pheromones[i][j] = evaporation
            pheromones[j][i] = evaporation
    for ant in ants:
        tour_length = ant.tour_length()
        for i in range(NUM_CITIES):
            j = (i + 1) % NUM_CITIES
            pheromones[ant.tour[i]][ant.tour[j]] += Q / tour_length
            pheromones[ant.tour[j]][ant.tour[i]] += Q / tour_length

def reset_ants(ants):
    for ant in ants:
        ant.visited = [False] * NUM_CITIES
        ant.tour = []

# %% [markdown]
# ACO Main Loop

# %%
def aco_main(iterations):
    ants = [Ant() for _ in range(NUM_ANTS)]
    best_tour = None
    best_length = float('inf')

    for _ in range(iterations):
        for ant in ants:
            ant.find_tour()
            length = ant.tour_length()
            if length < best_length:
                best_tour = ant.tour[:]
                best_length = length
        update_pheromones(ants)
        reset_ants(ants)

    return best_tour, best_length

# %% [markdown]
# Function to run ACO and display the results

# %%
def start_aco():
    global NUM_ANTS, NUM_CITIES, ALPHA, BETA, EVAPORATION_RATE, Q, INITIAL_PHEROMONE, MAX_DISTANCE
    NUM_ANTS = int(ants_entry.get())
    NUM_CITIES = int(cities_entry.get())
    ALPHA = 1.0
    BETA = 2.0
    EVAPORATION_RATE = 0.5
    Q = 100
    INITIAL_PHEROMONE = 1.0
    MAX_DISTANCE = 1000

    iterations = int(iterations_entry.get())
    best_tour, best_length = aco_main(iterations)
    output_text.config(state="normal")  # Enable editing of the text widget
    output_text.delete(1.0, tk.END)  # Clear the previous content
    output_text.insert(tk.END, f"Best Tour: {best_tour}\n")
    output_text.insert(tk.END, f"Best Tour Length: {best_length}\n")
    output_text.config(state="disabled")  # Make the text widget read-only

# %% [markdown]
# Function to create a NetworkX graph from city locations and pheromone levels

# %%
def create_networkx_graph():
    G = nx.Graph()
    for i in range(NUM_CITIES):
        G.add_node(i, pos=locations[i])
    for i in range(NUM_CITIES):
        for j in range(i + 1, NUM_CITIES):
            G.add_edge(i, j, weight=pheromones[i][j])
    return G

def draw_networkx():
    G = create_networkx_graph()
    pos = nx.get_node_attributes(G, 'pos')
    edge_labels = {(i, j): f"{pheromones[i][j]:.2f}" for i, j in G.edges}  # Format the label values
    edge_colors = [pheromones[i][j] for i, j in G.edges]

    plt.figure(figsize=(12, 12))  # Increase the figure size
    nx.draw(G, pos, with_labels=True, node_size=200, node_color='skyblue', edge_color=edge_colors, width=3, edge_cmap=plt.cm.inferno)  # Increase node size and edge width
    labels = nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red', font_size=10)  # Increase font size
    for (_, t), label in labels.items():
        label.set_text(label.get_text())

    plt.axis('off')
    plt.show()

# %% [markdown]
# GUI using Tkinter

# %%
import tkinter as tk
from tkinter import Label, Entry, Button, Text
from PIL import Image, ImageTk

def quit_application():
    window.quit()

window = tk.Tk()
window.title("Ant Colony Optimization")
window.geometry("500x400")  # Set window size

# Load the ant image
background = ImageTk.PhotoImage(file="/Users/noorfathima/Documents/college/year 2/Semester 4/tranforms : scientific computing lab/package/ant1.jpeg")

background_label = Label(window, image=background)
background_label.place(x=0, y=0, relwidth=1, relheight=1)


# Entry fields for the number of ants and cities
Label(window, text="Number of Ants:", anchor="e", fg="white", bg="black", font=("Arial", 12)).grid(row=0, column=0, padx=10, pady=10)  # Align to the right
ants_entry = Entry(window, bg="#B3585D", font=("Arial", 12))
ants_entry.grid(row=0, column=1, padx=10, pady=10)

Label(window, text="Number of Cities:", anchor="e", fg="white", bg="black", font=("Arial", 12)).grid(row=1, column=0, padx=10, pady=10)  # Align to the right
cities_entry = Entry(window, bg="#B3585D", font=("Arial", 12))
cities_entry.grid(row=1, column=1, padx=10, pady=10)

# Entry field for the number of iterations
Label(window, text="Number of Iterations:", anchor="e", fg="white", bg="black", font=("Arial", 12)).grid(row=2, column=0, padx=10, pady=10)  # Align to the right
iterations_entry = Entry(window, bg="#B3585D", font=("Arial", 12))
iterations_entry.grid(row=2, column=1, padx=10, pady=10)

# Text widget for output
output_text = Text(window, height=10, width=40, bg="#B7797C", font=("Arial", 12))
output_text.grid(row=3, column=0, columnspan=2, padx=10, pady=10)
output_text.tag_configure("center", justify='center')  # Configure text widget to center text
output_text.insert("1.0", "\n\n", "center")  # Insert an empty line with center alignment
output_text.config(state="disabled")  # Make the text widget read-only
Button(window, text="Start ACO", command=start_aco, bg="red", fg="black", font=("Arial", 14)).grid(row=5, column=0, columnspan=2, padx=10, pady=10, sticky="we")
Button(window, text="Show Network", command=draw_networkx, bg="blue", fg="black", font=("Arial", 14)).grid(row=6, column=0, columnspan=2, padx=10, pady=10, sticky="we")
#Button(window, text="Show Pie Plot", command=show_pie_plot, bg="blue", fg="black", font=("Arial", 14)).grid(row=7, column=0, columnspan=2, padx=10, pady=10, sticky="we")
#Button(window, text="Quit", command=quit_application, bg="gray", fg="black", font=("Arial", 14)).grid(row=7, column=0, columnspan=2, padx=10, pady=10, sticky="we")
window.mainloop()
# Out:
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 1.0
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 1.0
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 1.0
# Normalized probabilities: [0.0, 5.373894134320273e-06, 1.6487217121105928e-06, 2.3763203905447477e-06]
# Total probability: 9.398936236975613e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 1.0
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 1.0
# Normalized probabilities: [0.0, 0.0, 4.43538959988026e-06, 3.239184112149256e-06]
# Total probability: 7.674573712029516e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 1.0
# Normalized probabilities: [0.0, 0.0, 0.0, 8.737036240542042e-06]
# Total probability: 8.737036240542042e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 1.0
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 1.0
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 1.0
# Normalized probabilities: [2.3763203905447477e-06, 3.239184112149256e-06, 8.737036240542042e-06, 0.0]
# Total probability: 1.4352540743236046e-05
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 1.0
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 1.0
# Normalized probabilities: [5.373894134320273e-06, 0.0, 4.43538959988026e-06, 0.0]
# Total probability: 9.809283734200533e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 1.0
# Normalized probabilities: [0.0, 0.0, 1.6487217121105928e-06, 0.0]
# Total probability: 1.6487217121105928e-06
# Next city selected: 2
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.5528200951500479
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.5475259402282313
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.6003460353782792
# Normalized probabilities: [1.3136776644079464e-06, 1.77353732657687e-06, 5.245245067965761e-06, 0.0]
# Total probability: 8.332460058950578e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.5475259402282313
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.5528200951500479
# Normalized probabilities: [9.027179055980516e-07, 2.4519725006333386e-06, 0.0, 0.0]
# Total probability: 3.3546904062313903e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.6003460353782792
# Normalized probabilities: [0.0, 3.2261960380817657e-06, 0.0, 0.0]
# Total probability: 3.2261960380817657e-06
# Next city selected: 1
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.5528200951500479
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.5475259402282313
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.6003460353782792
# Normalized probabilities: [1.3136776644079464e-06, 1.77353732657687e-06, 5.245245067965761e-06, 0.0]
# Total probability: 8.332460058950578e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.5475259402282313
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.5528200951500479
# Normalized probabilities: [9.027179055980516e-07, 2.4519725006333386e-06, 0.0, 0.0]
# Total probability: 3.3546904062313903e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.6003460353782792
# Normalized probabilities: [3.2261960380817657e-06, 0.0, 0.0, 0.0]
# Total probability: 3.2261960380817657e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.40051905306741886
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.32128891034234697
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.3292301427250719
# Normalized probabilities: [0.0, 2.152346989962512e-06, 5.297160023417811e-07, 7.823563013395459e-07]
# Total probability: 3.4644192936438393e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.3292301427250719
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.32128891034234697
# Normalized probabilities: [0.0, 0.0, 1.4602639510098777e-06, 1.040713933790677e-06]
# Total probability: 2.5009778848005547e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.40051905306741886
# Normalized probabilities: [0.0, 0.0, 3.49934948167762e-06, 0.0]
# Total probability: 3.49934948167762e-06
# Next city selected: 2
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.40051905306741886
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.32128891034234697
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.3292301427250719
# Normalized probabilities: [0.0, 2.152346989962512e-06, 5.297160023417811e-07, 7.823563013395459e-07]
# Total probability: 3.4644192936438393e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.3292301427250719
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.32128891034234697
# Normalized probabilities: [0.0, 0.0, 1.4602639510098777e-06, 1.040713933790677e-06]
# Total probability: 2.5009778848005547e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.40051905306741886
# Normalized probabilities: [0.0, 0.0, 0.0, 3.49934948167762e-06]
# Total probability: 3.49934948167762e-06
# Next city selected: 3
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.20817039539940482
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.21743516651258388
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.30060556191198873
# Normalized probabilities: [3.432150507136458e-07, 9.644096761981472e-07, 0.0, 2.62640168853355e-06]
# Total probability: 3.934026415445343e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.30060556191198873
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.21743516651258388
# Normalized probabilities: [0.0, 1.615422465902886e-06, 0.0, 5.166956198053455e-07]
# Total probability: 2.1321180857082315e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.20817039539940482
# Normalized probabilities: [0.0, 0.0, 0.0, 6.743022373975807e-07]
# Total probability: 6.743022373975807e-07
# Next city selected: 3
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.30060556191198873
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.20817039539940482
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.21743516651258388
# Normalized probabilities: [0.0, 1.615422465902886e-06, 3.432150507136458e-07, 5.166956198053455e-07]
# Total probability: 2.4753331364218772e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.21743516651258388
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.20817039539940482
# Normalized probabilities: [0.0, 0.0, 9.644096761981472e-07, 6.743022373975807e-07]
# Total probability: 1.638711913595728e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.30060556191198873
# Normalized probabilities: [0.0, 0.0, 2.62640168853355e-06, 0.0]
# Total probability: 2.62640168853355e-06
# Next city selected: 2
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.24535466141245704
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.19913707815616508
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.10871758325629194
# Normalized probabilities: [0.0, 1.3185099757925395e-06, 3.283216244423334e-07, 2.5834780990267277e-07]
# Total probability: 1.9051794101375455e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.10871758325629194
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.24535466141245704
# Normalized probabilities: [0.0, 4.822048380990736e-07, 0.0, 2.1436725685465594e-06]
# Total probability: 2.625877406645633e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.19913707815616508
# Normalized probabilities: [0.0, 6.450416597032745e-07, 0.0, 0.0]
# Total probability: 6.450416597032745e-07
# Next city selected: 1
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.24535466141245704
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.19913707815616508
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.10871758325629194
# Normalized probabilities: [0.0, 1.3185099757925395e-06, 3.283216244423334e-07, 2.5834780990267277e-07]
# Total probability: 1.9051794101375455e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.10871758325629194
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.19913707815616508
# Normalized probabilities: [0.0, 0.0, 4.822048380990736e-07, 6.450416597032745e-07]
# Total probability: 1.1272464978023481e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.24535466141245704
# Normalized probabilities: [0.0, 0.0, 2.1436725685465594e-06, 0.0]
# Total probability: 2.1436725685465594e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.1946204195345452
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.05435879162814597
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.2177292111626912
# Normalized probabilities: [3.2087491130667724e-07, 2.411024190495368e-07, 0.0, 1.902308008553064e-06]
# Total probability: 2.4642853389092783e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.05435879162814597
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.1946204195345452
# Normalized probabilities: [1.2917390495133638e-07, 6.304113708561215e-07, 0.0, 0.0]
# Total probability: 7.595852758074578e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.2177292111626912
# Normalized probabilities: [1.1700537307373664e-06, 0.0, 0.0, 0.0]
# Total probability: 1.1700537307373664e-06
# Next city selected: 0
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.2177292111626912
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.05435879162814597
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.1946204195345452
# Normalized probabilities: [1.1700537307373664e-06, 0.0, 2.411024190495368e-07, 6.304113708561215e-07]
# Total probability: 2.0415675206430246e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.1946204195345452
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.05435879162814597
# Normalized probabilities: [0.0, 0.0, 3.2087491130667724e-07, 1.2917390495133638e-07]
# Total probability: 4.500488162580136e-07
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.2177292111626912
# Normalized probabilities: [0.0, 0.0, 0.0, 1.902308008553064e-06]
# Total probability: 1.902308008553064e-06
# Next city selected: 3
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.20391648603780826
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.027179395814072985
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.19236209022373527
# Normalized probabilities: [1.0958256082097797e-06, 0.0, 1.205512095247684e-07, 6.23096226432545e-07]
# Total probability: 1.8394730441670929e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.027179395814072985
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.20391648603780826
# Normalized probabilities: [6.458695247566819e-08, 0.0, 1.7816257285563162e-06, 0.0]
# Total probability: 1.8462126810319843e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.19236209022373527
# Normalized probabilities: [3.1715155473884914e-07, 0.0, 0.0, 0.0]
# Total probability: 3.1715155473884914e-07
# Next city selected: 0
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.027179395814072985
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.19236209022373527
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.20391648603780826
# Normalized probabilities: [6.458695247566819e-08, 6.23096226432545e-07, 1.7816257285563162e-06, 0.0]
# Total probability: 2.4693089074645294e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.19236209022373527
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.027179395814072985
# Normalized probabilities: [3.1715155473884914e-07, 1.205512095247684e-07, 0.0, 0.0]
# Total probability: 4.3770276426361754e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.20391648603780826
# Normalized probabilities: [1.0958256082097797e-06, 0.0, 0.0, 0.0]
# Total probability: 1.0958256082097797e-06
# Next city selected: 0
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.06640979305708443
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.14370698534009896
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.2023042783971834
# Normalized probabilities: [1.5781094537340674e-07, 4.6549338371851455e-07, 1.767539811972898e-06, 0.0]
# Total probability: 2.390844141064819e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.14370698534009896
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.06640979305708443
# Normalized probabilities: [2.369328269121798e-07, 2.945533054555926e-07, 0.0, 0.0]
# Total probability: 5.314861323677724e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.2023042783971834
# Normalized probabilities: [1.0871617750265194e-06, 0.0, 0.0, 0.0]
# Total probability: 1.0871617750265194e-06
# Next city selected: 0
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.2023042783971834
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.06640979305708443
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.14370698534009896
# Normalized probabilities: [1.0871617750265194e-06, 0.0, 2.945533054555926e-07, 4.6549338371851455e-07]
# Total probability: 1.8472084642006266e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.14370698534009896
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.2023042783971834
# Normalized probabilities: [2.369328269121798e-07, 0.0, 0.0, 1.767539811972898e-06]
# Total probability: 2.0044726388850775e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.06640979305708443
# Normalized probabilities: [0.0, 0.0, 0.0, 1.5781094537340674e-07]
# Total probability: 1.5781094537340674e-07
# Next city selected: 3
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.11253768412924697
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.12670918313778765
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.15397223434863963
# Normalized probabilities: [1.8554332325453315e-07, 5.620045930986665e-07, 0.0, 1.3452609915412967e-06]
# Total probability: 2.0928089078944963e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.12670918313778765
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.11253768412924697
# Normalized probabilities: [3.011016155595935e-07, 3.6453027844952827e-07, 0.0, 0.0]
# Total probability: 6.656318940091218e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.15397223434863963
# Normalized probabilities: [8.27430487014341e-07, 0.0, 0.0, 0.0]
# Total probability: 8.27430487014341e-07
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.15397223434863963
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.11253768412924697
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.12670918313778765
# Normalized probabilities: [0.0, 8.27430487014341e-07, 1.8554332325453315e-07, 3.011016155595935e-07]
# Total probability: 1.3140754258284676e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.11253768412924697
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.15397223434863963
# Normalized probabilities: [0.0, 3.6453027844952827e-07, 1.3452609915412967e-06, 0.0]
# Total probability: 1.709791269990825e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.12670918313778765
# Normalized probabilities: [0.0, 5.620045930986665e-07, 0.0, 0.0]
# Total probability: 5.620045930986665e-07
# Next city selected: 1
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.11617468671894177
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.10379478229285483
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.17733215255259907
# Normalized probabilities: [2.760682769153694e-07, 3.362104097270063e-07, 1.549357443465388e-06, 0.0]
# Total probability: 2.161636130107764e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.10379478229285483
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.11617468671894177
# Normalized probabilities: [1.7112871117002186e-07, 5.152799972425417e-07, 0.0, 0.0]
# Total probability: 6.864087084125635e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.17733215255259907
# Normalized probabilities: [9.529642144288e-07, 0.0, 0.0, 0.0]
# Total probability: 9.529642144288e-07
# Next city selected: 0
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.11617468671894177
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.10379478229285483
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.17733215255259907
# Normalized probabilities: [2.760682769153694e-07, 3.362104097270063e-07, 1.549357443465388e-06, 0.0]
# Total probability: 2.161636130107764e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.10379478229285483
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.11617468671894177
# Normalized probabilities: [1.7112871117002186e-07, 5.152799972425417e-07, 0.0, 0.0]
# Total probability: 6.864087084125635e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.17733215255259907
# Normalized probabilities: [9.529642144288e-07, 0.0, 0.0, 0.0]
# Total probability: 9.529642144288e-07
# Next city selected: 0
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.05189739114642741
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.16372753365956674
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.1943062665763954
# Normalized probabilities: [8.556435558501093e-08, 7.261954000076876e-07, 0.0, 1.6976608928423896e-06]
# Total probability: 2.5094206484350882e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.1943062665763954
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.05189739114642741
# Normalized probabilities: [1.0441813062165627e-06, 0.0, 0.0, 1.6810520486350314e-07]
# Total probability: 1.212286511080066e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.16372753365956674
# Normalized probabilities: [0.0, 0.0, 0.0, 3.8906907672883e-07]
# Total probability: 3.8906907672883e-07
# Next city selected: 3
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.1943062665763954
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.16372753365956674
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.05189739114642741
# Normalized probabilities: [1.0441813062165627e-06, 0.0, 7.261954000076876e-07, 1.6810520486350314e-07]
# Total probability: 1.9384819110877533e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.05189739114642741
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.16372753365956674
# Normalized probabilities: [0.0, 0.0, 8.556435558501093e-08, 3.8906907672883e-07]
# Total probability: 4.746334323138409e-07
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.1943062665763954
# Normalized probabilities: [0.0, 0.0, 1.6976608928423896e-06, 0.0]
# Total probability: 1.6976608928423896e-06
# Next city selected: 2
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.20279332358829358
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.025948695573213706
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.18750395712987925
# Normalized probabilities: [0.0, 1.089789852110444e-06, 4.2782177792505465e-08, 4.4556947663556026e-07]
# Total probability: 1.5781415065385096e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.025948695573213706
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.20279332358829358
# Normalized probabilities: [0.0, 8.405260243175157e-08, 1.7718126175308904e-06, 0.0]
# Total probability: 1.855865219962642e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.18750395712987925
# Normalized probabilities: [0.0, 8.316531013902606e-07, 0.0, 0.0]
# Total probability: 8.316531013902606e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.20279332358829358
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.18750395712987925
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.025948695573213706
# Normalized probabilities: [1.089789852110444e-06, 0.0, 8.316531013902606e-07, 8.405260243175157e-08]
# Total probability: 2.0054955559324564e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.025948695573213706
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.20279332358829358
# Normalized probabilities: [4.2782177792505465e-08, 0.0, 0.0, 1.7718126175308904e-06]
# Total probability: 1.814594795323396e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.18750395712987925
# Normalized probabilities: [4.4556947663556026e-07, 0.0, 0.0, 0.0]
# Total probability: 4.4556947663556026e-07
# Next city selected: 0
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.1993921688650355
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.012974347786606853
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.20703685209424266
# Normalized probabilities: [4.738196765889254e-07, 4.2026301215875785e-08, 1.8088884798751409e-06, 0.0]
# Total probability: 2.324734457679942e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.012974347786606853
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.1993921688650355
# Normalized probabilities: [2.1391088896252733e-08, 8.843819520815471e-07, 0.0, 0.0]
# Total probability: 9.057730409777998e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.20703685209424266
# Normalized probabilities: [1.1125941250573845e-06, 0.0, 0.0, 0.0]
# Total probability: 1.1125941250573845e-06
# Next city selected: 0
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.20703685209424266
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.1993921688650355
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.012974347786606853
# Normalized probabilities: [1.1125941250573845e-06, 0.0, 8.843819520815471e-07, 4.2026301215875785e-08]
# Total probability: 2.0390023783548075e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.012974347786606853
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.20703685209424266
# Normalized probabilities: [2.1391088896252733e-08, 0.0, 0.0, 1.8088884798751409e-06]
# Total probability: 1.8302795687713936e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.1993921688650355
# Normalized probabilities: [4.738196765889254e-07, 0.0, 0.0, 0.0]
# Total probability: 4.738196765889254e-07
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.2091586163472172
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.006487173893303427
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.20533627473261362
# Normalized probabilities: [0.0, 1.1239962615308549e-06, 1.0695544448126366e-08, 4.87944776565608e-07]
# Total probability: 1.622636582544589e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.20533627473261362
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.006487173893303427
# Normalized probabilities: [0.0, 0.0, 9.107463774271904e-07, 2.1013150607937892e-08]
# Total probability: 9.317595280351283e-07
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.2091586163472172
# Normalized probabilities: [0.0, 0.0, 0.0, 1.8274264110472658e-06]
# Total probability: 1.8274264110472658e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.20533627473261362
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.006487173893303427
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.2091586163472172
# Normalized probabilities: [4.87944776565608e-07, 2.1013150607937892e-08, 1.8274264110472658e-06, 0.0]
# Total probability: 2.3363843382208117e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.2091586163472172
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.006487173893303427
# Normalized probabilities: [0.0, 1.1239962615308549e-06, 1.0695544448126366e-08, 0.0]
# Total probability: 1.1346918059789811e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.20533627473261362
# Normalized probabilities: [0.0, 0.0, 9.107463774271904e-07, 0.0]
# Total probability: 9.107463774271904e-07
# Next city selected: 2
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.21021949847370447
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.20830832766640267
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.0032435869466517133
# Normalized probabilities: [1.12969732976759e-06, 0.0, 9.239285901000119e-07, 1.0506575303968946e-08]
# Total probability: 2.064132495171571e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.0032435869466517133
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.21021949847370447
# Normalized probabilities: [5.347772224063183e-09, 0.0, 0.0, 1.8366953766333285e-06]
# Total probability: 1.8420431488573917e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.20830832766640267
# Normalized probabilities: [4.950073265539493e-07, 0.0, 0.0, 0.0]
# Total probability: 4.950073265539493e-07
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.21021949847370447
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.0032435869466517133
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.20830832766640267
# Normalized probabilities: [0.0, 1.12969732976759e-06, 5.347772224063183e-09, 4.950073265539493e-07]
# Total probability: 1.6300524285456024e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.20830832766640267
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.0032435869466517133
# Normalized probabilities: [0.0, 0.0, 9.239285901000119e-07, 1.0506575303968946e-08]
# Total probability: 9.344351654039809e-07
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.21021949847370447
# Normalized probabilities: [0.0, 0.0, 0.0, 1.8366953766333285e-06]
# Total probability: 1.8366953766333285e-06
# Next city selected: 3
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.2107499395369481
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.0016217934733258567
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.2097943541332972
# Normalized probabilities: [0.0, 1.1325478638859575e-06, 2.6738861120315916e-09, 4.985386015481199e-07]
# Total probability: 1.633760351546109e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.2097943541332972
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.0016217934733258567
# Normalized probabilities: [0.0, 0.0, 9.305196964364227e-07, 5.253287651984473e-09]
# Total probability: 9.357729840884072e-07
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.2107499395369481
# Normalized probabilities: [0.0, 0.0, 0.0, 1.8413298594263598e-06]
# Total probability: 1.8413298594263598e-06
# Next city selected: 3
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.2107499395369481
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.2097943541332972
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.0016217934733258567
# Normalized probabilities: [1.1325478638859575e-06, 0.0, 9.305196964364227e-07, 5.253287651984473e-09]
# Total probability: 2.0683208479743645e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.0016217934733258567
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.2097943541332972
# Normalized probabilities: [0.0, 0.0, 2.6738861120315916e-09, 4.985386015481199e-07]
# Total probability: 5.012124876601515e-07
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.2107499395369481
# Normalized probabilities: [0.0, 0.0, 1.8413298594263598e-06, 0.0]
# Total probability: 1.8413298594263598e-06
# Next city selected: 2
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.2110151600685699
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.0008108967366629283
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.21053736736674447
# Normalized probabilities: [0.0, 1.1339731309451414e-06, 1.3369430560157958e-09, 5.003042390452052e-07]
# Total probability: 1.6356143130463623e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.21053736736674447
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.0008108967366629283
# Normalized probabilities: [0.0, 0.0, 9.338152496046281e-07, 2.6266438259922366e-09]
# Total probability: 9.364418934306203e-07
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.2110151600685699
# Normalized probabilities: [0.0, 0.0, 0.0, 1.8436471008228753e-06]
# Total probability: 1.8436471008228753e-06
# Next city selected: 3
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.2110151600685699
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.21053736736674447
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.0008108967366629283
# Normalized probabilities: [1.1339731309451414e-06, 0.0, 9.338152496046281e-07, 2.6266438259922366e-09]
# Total probability: 2.0704150243757616e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.0008108967366629283
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.21053736736674447
# Normalized probabilities: [0.0, 0.0, 1.3369430560157958e-09, 5.003042390452052e-07]
# Total probability: 5.016411821012211e-07
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.2110151600685699
# Normalized probabilities: [0.0, 0.0, 1.8436471008228753e-06, 0.0]
# Total probability: 1.8436471008228753e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.00040544836833146416
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.2109088739834681
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.2111477703343808
# Normalized probabilities: [6.684715280078979e-10, 9.354630261887309e-07, 0.0, 1.8448057215211332e-06]
# Total probability: 2.7809372192378718e-06
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.2109088739834681
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.00040544836833146416
# Normalized probabilities: [5.011870577937479e-07, 1.3133219129961183e-09, 0.0, 0.0]
# Total probability: 5.02500379706744e-07
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.2111477703343808
# Normalized probabilities: [0.0, 1.1346857644747331e-06, 0.0, 0.0]
# Total probability: 1.1346857644747331e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.2111477703343808
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.2109088739834681
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.00040544836833146416
# Normalized probabilities: [1.1346857644747331e-06, 0.0, 9.354630261887309e-07, 1.3133219129961183e-09]
# Total probability: 2.0714621125764603e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.00040544836833146416
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.2109088739834681
# Normalized probabilities: [0.0, 0.0, 6.684715280078979e-10, 5.011870577937479e-07]
# Total probability: 5.018555293217558e-07
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.2111477703343808
# Normalized probabilities: [0.0, 0.0, 1.8448057215211332e-06, 0.0]
# Total probability: 1.8448057215211332e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.00020272418416573208
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.21109462729182993
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.21121407546728627
# Normalized probabilities: [3.3423576400394895e-10, 9.362869144807823e-07, 0.0, 1.845385031870262e-06]
# Total probability: 2.7820061821150482e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.21121407546728627
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.00020272418416573208
# Normalized probabilities: [1.135042081239529e-06, 0.0, 0.0, 6.566609564980591e-10]
# Total probability: 1.1356987421960272e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.21109462729182993
# Normalized probabilities: [0.0, 0.0, 0.0, 5.016284671680193e-07]
# Total probability: 5.016284671680193e-07
# Next city selected: 3
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.21109462729182993
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.00020272418416573208
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.21121407546728627
# Normalized probabilities: [5.016284671680193e-07, 6.566609564980591e-10, 1.845385031870262e-06, 0.0]
# Total probability: 2.3476701599947795e-06
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 0
# Pheromone level for edge ( 2 , 0 ): 0.00020272418416573208
# Calculating probability for city: 1
# Pheromone level for edge ( 2 , 1 ): 0.21109462729182993
# Normalized probabilities: [3.3423576400394895e-10, 9.362869144807823e-07, 0.0, 0.0]
# Total probability: 9.366211502447862e-07
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 0
# Pheromone level for edge ( 1 , 0 ): 0.21121407546728627
# Normalized probabilities: [1.135042081239529e-06, 0.0, 0.0, 0.0]
# Total probability: 1.135042081239529e-06
# Next city selected: 0
# Current city: 3
# Calculating probability for city: 0
# Pheromone level for edge ( 3 , 0 ): 0.21118750394601082
# Calculating probability for city: 1
# Pheromone level for edge ( 3 , 1 ): 0.00010136209208286604
# Calculating probability for city: 2
# Pheromone level for edge ( 3 , 2 ): 0.211247228033739
# Normalized probabilities: [5.018491718551549e-07, 3.2833047824902957e-10, 1.8456746870448264e-06, 0.0]
# Total probability: 2.3478521893782304e-06
# Next city selected: 0
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.211247228033739
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.00010136209208286604
# Normalized probabilities: [0.0, 1.1352202396219272e-06, 1.6711788200197447e-10, 0.0]
# Total probability: 1.135387357503929e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.21118750394601082
# Normalized probabilities: [0.0, 0.0, 9.366988586268078e-07, 0.0]
# Total probability: 9.366988586268078e-07
# Next city selected: 2
# Current city: 0
# Calculating probability for city: 1
# Pheromone level for edge ( 0 , 1 ): 0.211247228033739
# Calculating probability for city: 2
# Pheromone level for edge ( 0 , 2 ): 0.00010136209208286604
# Calculating probability for city: 3
# Pheromone level for edge ( 0 , 3 ): 0.21118750394601082
# Normalized probabilities: [0.0, 1.1352202396219272e-06, 1.6711788200197447e-10, 5.018491718551549e-07]
# Total probability: 1.637236529359084e-06
# Next city selected: 1
# Current city: 1
# Calculating probability for city: 2
# Pheromone level for edge ( 1 , 2 ): 0.21118750394601082
# Calculating probability for city: 3
# Pheromone level for edge ( 1 , 3 ): 0.00010136209208286604
# Normalized probabilities: [0.0, 0.0, 9.366988586268078e-07, 3.2833047824902957e-10]
# Total probability: 9.370271891050569e-07
# Next city selected: 2
# Current city: 2
# Calculating probability for city: 3
# Pheromone level for edge ( 2 , 3 ): 0.211247228033739
# Normalized probabilities: [0.0, 0.0, 0.0, 1.8456746870448264e-06]
# Total probability: 1.8456746870448264e-06
# Next city selected: 3
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
